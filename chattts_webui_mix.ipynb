# %% [markdown]
# <a href="https://colab.research.google.com/github/6830920/MoneyPrinterTurbo/blob/main/chattts_webui_mix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > 🌟 如果你觉得 ChatTTS 和 ChatTTS_colab 项目对你有帮助，请访问以下链接给它们点个星星吧！🌟
#
# - [ChatTTS 项目](https://github.com/2noise/ChatTTS)
#
# - [ChatTTS_colab 项目](https://github.com/6drf21e/ChatTTS_colab)
#
# 感谢你的支持！
#
# # 运行方法
#
# - 点击菜单栏的--代码执行程序--全部运行即可
# - 执行后在下方的日志中找到类似
#
#   Running on public URL: https://**************.gradio.live  <-这个就是可以访问的公网地址
#
# 安装包的时候提示要重启 请点**"否"**

# %%
# !git clone -q https://github.com/6drf21e/ChatTTS_colab
# %cd ChatTTS_colab
# !git clone -q https://github.com/2noise/ChatTTS
# %cd ChatTTS
# !git checkout -q e6412b1
# %cd ..
# !mv ChatTTS abc
# !mv abc/* /content/ChatTTS_colab/
# !pip install -q omegaconf vocos vector_quantize_pytorch gradio cn2an pypinyin openai jieba WeTextProcessing python-dotenv
# !pip install torch==2.5.0
# 启动 Gradio 有公网地址
# !python webui_mix.py --share
# Out:
# /content/ChatTTS_colab
# /content/ChatTTS_colab/ChatTTS
# /content/ChatTTS_colab
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 98.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 MB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.0/837.0 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.7/137.7 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 111.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.1 MB/s eta 0:00:00
#   Building wheel for encodec (setup.py) ... done
# 2025-05-19 11:42:44.121428: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747654964.385513     879 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747654964.453140     879 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-19 11:42:44.973044: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading ChatTTS model...
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
# GPT.pt:   0% 0.00/901M [00:00<?, ?B/s]
#
# DVAE.pt:   0% 0.00/27.7M [00:00<?, ?B/s]
#
#
# DVAE_full.pt:   0% 0.00/60.4M [00:00<?, ?B/s]
#
#
#
# Decoder.pt:   0% 0.00/104M [00:00<?, ?B/s]
#
#
#
#
# Vocos.pt:   0% 0.00/54.4M [00:00<?, ?B/s]
#
#
#
# Decoder.pt:  10% 10.5M/104M [00:00<00:01, 84.2MB/s]
# GPT.pt:   1% 10.5M/901M [00:00<00:11, 78.7MB/s]
#
#
#
#
# Vocos.pt:  19% 10.5M/54.4M [00:00<00:00, 91.1MB/s]
#
# DVAE.pt:  38% 10.5M/27.7M [00:00<00:00, 72.8MB/s]
#
#
# DVAE_full.pt:  17% 10.5M/60.4M [00:00<00:00, 59.8MB/s]
#
#
#
#
#
# spk_stat.pt: 100% 4.26k/4.26k [00:00<00:00, 9.15MB/s]
#
#
#
#
#
#
# decoder.yaml: 100% 117/117 [00:00<00:00, 476kB/s]
#
#
#
#
# Decoder.pt:  20% 21.0M/104M [00:00<00:00, 90.4MB/s]
#
#
#
#
# Vocos.pt:  39% 21.0M/54.4M [00:00<00:00, 87.2MB/s]
# GPT.pt:   2% 21.0M/901M [00:00<00:12, 73.3MB/s]
#
# DVAE.pt:  76% 21.0M/27.7M [00:00<00:00, 74.6MB/s]
#
#
# DVAE_full.pt:  35% 21.0M/60.4M [00:00<00:00, 74.4MB/s]
#
#
#
# DVAE.pt: 100% 27.7M/27.7M [00:00<00:00, 65.9MB/s]
# Fetching 12 files:   8% 1/12 [00:00<00:07,  1.42it/s]
#
#
#
#
# Vocos.pt:  58% 31.5M/54.4M [00:00<00:00, 71.3MB/s]
# GPT.pt:   3% 31.5M/901M [00:00<00:12, 68.2MB/s]
#
#
# DVAE_full.pt:  52% 31.5M/60.4M [00:00<00:00, 63.5MB/s]
#
#
#
# Decoder.pt:  40% 41.9M/104M [00:00<00:00, 82.3MB/s]
#
# tokenizer.pt: 100% 337k/337k [00:00<00:00, 33.7MB/s]
#
#
#
#
#
# Vocos.pt:  77% 41.9M/54.4M [00:00<00:00, 71.7MB/s]
# GPT.pt:   5% 41.9M/901M [00:00<00:12, 68.8MB/s]
#
#
# DVAE_full.pt:  69% 41.9M/60.4M [00:00<00:00, 70.9MB/s]
#
#
#
# Decoder.pt:  61% 62.9M/104M [00:00<00:00, 103MB/s]
#
#
#
#
# Vocos.pt: 100% 54.4M/54.4M [00:00<00:00, 77.3MB/s]
#
# GPT.pt:   6% 52.4M/901M [00:00<00:11, 73.0MB/s]
#
#
# DVAE_full.pt:  87% 52.4M/60.4M [00:00<00:00, 73.8MB/s]
#
# gpt.yaml: 100% 346/346 [00:00<00:00, 2.38MB/s]
# DVAE_full.pt: 100% 60.4M/60.4M [00:00<00:00, 75.0MB/s]
# Fetching 12 files:  17% 2/12 [00:01<00:05,  1.95it/s]
#
#
#
# Decoder.pt:  81% 83.9M/104M [00:00<00:00, 115MB/s]
# GPT.pt:   8% 73.4M/901M [00:00<00:08, 97.0MB/s]
#
# dvae.yaml: 100% 143/143 [00:00<00:00, 613kB/s]
# Decoder.pt: 100% 104M/104M [00:00<00:00, 113MB/s]
# Fetching 12 files:  25% 3/12 [00:01<00:03,  3.00it/s]
#
# path.yaml: 100% 309/309 [00:00<00:00, 890kB/s]
#
# GPT.pt:  12% 105M/901M [00:00<00:05, 150MB/s]
#
# vocos.yaml: 100% 460/460 [00:00<00:00, 2.74MB/s]
#
# GPT.pt:  16% 147M/901M [00:01<00:03, 216MB/s]
# GPT.pt:  20% 178M/901M [00:01<00:03, 227MB/s]
# GPT.pt:  23% 210M/901M [00:01<00:02, 237MB/s]
# GPT.pt:  27% 241M/901M [00:01<00:02, 228MB/s]
# GPT.pt:  30% 273M/901M [00:01<00:02, 249MB/s]
# GPT.pt:  34% 304M/901M [00:01<00:02, 242MB/s]
# GPT.pt:  37% 336M/901M [00:01<00:02, 235MB/s]
# GPT.pt:  41% 367M/901M [00:01<00:02, 235MB/s]
# GPT.pt:  44% 398M/901M [00:03<00:10, 46.7MB/s]
# GPT.pt:  47% 419M/901M [00:04<00:09, 51.0MB/s]
# GPT.pt:  52% 472M/901M [00:04<00:05, 85.0MB/s]
# GPT.pt:  58% 524M/901M [00:04<00:03, 124MB/s]
# GPT.pt:  63% 566M/901M [00:04<00:02, 152MB/s]
# GPT.pt:  68% 608M/901M [00:04<00:01, 187MB/s]
# GPT.pt:  72% 650M/901M [00:04<00:01, 218MB/s]
# GPT.pt:  77% 692M/901M [00:04<00:00, 253MB/s]
# GPT.pt:  83% 744M/901M [00:05<00:00, 294MB/s]
# GPT.pt:  87% 786M/901M [00:05<00:00, 317MB/s]
# GPT.pt:  92% 828M/901M [00:05<00:00, 309MB/s]
# GPT.pt: 100% 901M/901M [00:05<00:00, 161MB/s]
# Fetching 12 files: 100% 12/12 [00:05<00:00,  2.05it/s]
# Traceback (most recent call last):
#   File "/content/ChatTTS_colab/webui_mix.py", line 46, in <module>
#     chat = load_chat_tts_model(source=args.source, local_path=args.local_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ChatTTS_colab/tts_model.py", line 25, in load_chat_tts_model
#     chat.load_models(source=source, force_redownload=force_redownload, custom_path=local_path, compile=False)
#   File "/content/ChatTTS_colab/ChatTTS/core.py", line 81, in load_models
#     self._load(**{k: os.path.join(download_path, v) for k, v in OmegaConf.load(os.path.join(download_path, 'config', 'path.yaml')).items()}, **kwargs)
#   File "/content/ChatTTS_colab/ChatTTS/core.py", line 144, in _load
#     tokenizer = torch.load(tokenizer_path, map_location='cpu')
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1470, in load
#     raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# _pickle.UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL transformers.models.bert.tokenization_bert_fast.BertTokenizerFast was not an allowed global by default. Please use `torch.serialization.add_safe_globals([BertTokenizerFast])` or the `torch.serialization.safe_globals([BertTokenizerFast])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %%
from google.colab import drive
drive.mount('/content/drive')
